# %% [markdown]
# Below there is a script to read csv file. It contains information about audio features from just 10 songs. You can find the songs in a public Spotify playlist here.
#
# Import the csv file into a pandas dataframe.
# Look at the raw data.
# Listen to those songs.
# While listening to the songs and looking at the data, try to start developing a sense for which features are the most descriptive in terms of separating songs that are different between them. Let’s get started by looking at the danceability feature:
#
# A song like The Real Slim Shady by Eminem has a danceability value of almost 1 (the maximum), while a piano song by Brahms has an energy of 0.18. Do these extremes make sense while listening to the songs?
# In Silence, by Amelie Lens, has a danceability value that is almost equal than Sultans of Swing by the Dire Straits. Why do you think that this feature is not able to capture the difference between these songs? Are there other features able to capture the difference? Which ones?
# Try to do the same for the rest of the audio features and note which ones do you think that matter the most, and which ones you might consider to exclude.

# %%
import pandas as pd
url =   'https://drive.google.com/file/d/1s8u0PB125f2teAkV2wpkdnz4E76JpuAO/view?usp=share_link'  
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df_audio_features = pd.read_csv(path)

# %%
df_audio_features
# Out:
#   song_name                                                                 \
# 0  My Band                                       ...
# 1  The Real Slim Shady                           ...
# 2  Águas De Março                                ...
# 3  The Girl From Ipanema                         ...
# 4  Paint It, Black                               ...
# 5  Sultans Of Swing                              ...
# 6  Space Raiders - Charlotte de Witte Remix      ...
# 7  In Silence                                    ...
# 8  Wiegenlied, Op. 49, No. 4 (Arr. for Cello and ...
# 9  Nocturne en mi bémol majeur opus 9 n°2: Ballad...
#
#    artist                 danceability   energy    key   loudness   mode   \
# 0  D12                            0.851   0.84900     1     -3.383      0
# 1  Eminem                         0.949   0.66100     5     -4.244      0
# 2  Antônio Carlos Jobim           0.642   0.33900     3    -15.503      1
# ...

# %%
import pandas as pd
path='/df_audio_features_10'
music_df = pd.read_csv(path)
music_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-aa9e5acfa781> in <cell line: 3>()
#       1 import pandas as pd
#       2 path='/df_audio_features_10'
# ----> 3 music_df = pd.read_csv(path)
#       4 music_df
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
